# %%
from torchlite.autograd.tensor import Tensor

# %%
t1 = Tensor([1, 2, 3])
t1.dtype
# Out:
# dtype('float32')

# %%
t2 = Tensor([4, 5, 6])
t1 + t2
# Out:
# Tensor(data=[5. 7. 9.]), grad=None)

# %%
t1 - t2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 t1 - t2
#
# TypeError: unsupported operand type(s) for -: 'Tensor' and 'Tensor'
